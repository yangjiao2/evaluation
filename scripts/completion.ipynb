# %%
#https://nvidia.sharepoint.com/sites/nvbuild/SitePages/Endpoints-for-Internal-Development-Use.aspx?xsdata=...%3D%3D&sdata=SVh2OUVuZVgzRGFsZVptclovQ0I3RERnRVdCK3pVdFBnSEZBbGlwb0Fscz0%3D&ovuser=43083d15-7273-40c1-b7db-39efd9ccc17a%2Cyangj%40nvidia.com&OR=Teams-HL&CT=1736458657900&clickparams=eyJBcHBOYW1lIjoiVGVhbXMtRGVza3RvcCIsIkFwcFZlcnNpb24iOiI1MC8yNDEyMDEwMDIxMyIsIkhhc0ZlZGVyYXRlZFVzZXIiOmZhbHNlfQ%3D%3D 
NVDEV_KEY = ""


SLACK_TOKEN = ""

# %%
# ! curl https://integrate.api.nvidia.com/v1/chat/completions \
# -H f"Authorization: Bearer {NVDEV_KEY}" \
# -H "Content-Type: application/json" \
# -H "Accept: application/json" \
# -d '{
# "model": "nvdev/meta/llama-3.3-70b-instruct",
# "messages": [
#   {
#     "role": "user",
#     "content": "Hello!"
#   }
# ],
# "max_tokens": 512,
# "temperature": 1.00,
# "top_p": 1.00,
# "stream": false
# }'

# %%
import requests

url = "https://slack.com/api/search.messages"
query_params = {
    "query": '"Jessica Jiao" after:01-04-2025 before:01-07-2025',
    "count": 99,
    "page": 1
}
headers = {
    "Authorization": f"Bearer {SLACK_TOKEN}"
}

response = requests.get(url, headers=headers, params=query_params)

# Print the response in JSON format
# print(response.json())
